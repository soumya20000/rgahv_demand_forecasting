# %%
import pandas as pd
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from scipy import stats
from statsmodels.tsa.seasonal import seasonal_decompose

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)
# %matplotlib inline
#%matplotlib notebook
sns.set(rc={'figure.figsize':(11.7,8.27)})
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime,timedelta
from itertools import product
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
df = pd.read_pickle('unpiv_df_f1.pkl')

# %%
# filte keys which are available in 2019-2020
df2 = df.loc[df.index <= pd.to_datetime('2019-06-01')]

#df3 = df2.groupby('key')['siv_demand'].apply(lambda x: (x==0).sum()).reset_index(name='count')
df3 = df2.query('siv_demand ==0').groupby('key').size().reset_index(name='count_zeros')
#df3 = df2.groupby('key')['siv_demand'].apply(lambda x: (x==0).count()).reset_index(name='count_demand')# not working
#df3.sort_values('key',ascending=False)

# df3.sample(20)
# df3.count_zeros.value_counts().sort_values()
keys_model = df3.query('count_zeros <= 6').key.tolist()
# len(keys_model)
# model_df = df2.loc[df2.key.isin(keys_model)]

# %%
model_df.shape
# Out:
# (3906, 4)

# %%
# fixed params
base_time_frame = pd.date_range(start="2016-01-01",end="2020-02-01",freq="MS")
train_data_max_date = datetime.strptime('20190701',"%Y%m%d")
forecast_range = list(filter(lambda x: x > train_data_max_date,base_time_frame))
res = list()

# %%
res = list()
for key in keys_model:
    tm_df = df.query('key == @key')['siv_demand'].sort_index()
    #ser = ser[ser<=ser.quantile(0.99)]
    #ser = ser[ser < ser.quantile(0.75)+ (ser.quantile(0.75)-ser.quantile(0.25))*2]
    #tm_df = pd.DataFrame(index=base_time_frame)
    #tm_df = pd.concat([tm_df,ser],axis=1)
    sample_data = tm_df.copy()
    sample_data.loc[sample_data==0] = np.nan
    sample_data = sample_data.interpolate(method='time')
    tm_df.fillna(0,inplace=True)
    print(key)
    
    for tm in forecast_range:
        train_data = sample_data.loc[:tm][:-2]  # setting train data 2 months prior to forecast month
        demand_act = tm_df.loc[tm]
        naive_fcst = train_data.iloc[-1]
        avg_fcst =  train_data.mean()
        sma2 = train_data.rolling(2).mean().iloc[-1]
        sma5 = train_data.rolling(5).mean().iloc[-1]
        fit2 = SimpleExpSmoothing(np.asarray(train_data)).fit(smoothing_level=0.6,optimized=False)
        ses = fit2.forecast(2)[1]
        fit1 = Holt(np.asarray(train_data)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
        holt = fit1.forecast(2)[1]
        hwm_model = ExponentialSmoothing(np.asarray(train_data) ,seasonal_periods=7 ,trend='add', seasonal
                ='add',).fit()
        hwm = hwm_model.forecast(2)[1]
        #print(tm.date())
        fcst = 0
        stderr = 0
        up_conf = 0
        low_conf = 0
        try:
            model = ARIMA(train_data, order=(4,1,2))
            model_fit = model.fit(transparams=False,disp=-1,trend='c',maxiter = 5000)#start_params =5
            #print(model_fit.forecast())
            fcst,stderr,conf = model_fit.forecast(steps =2)
            fcst = 0 if np.isnan(round(fcst[1])) else round(fcst[1])
            stderr = 0 if np.isnan(round(stderr[1])) else round(stderr[1])
            low_conf = 0 if np.isnan(round(conf[1][0])) else round(conf[1][0])
            up_conf = 0 if np.isnan(round(conf[1][1])) else round(conf[1][1])
            #print(fcst,stderr)
        except Exception as e:
            print(e)
            fcst = 0
            fcst = 0
            stderr = 0
            up_conf = 0
            low_conf = 0
        
        res.append([key,tm,demand_act,fcst,stderr,low_conf,up_conf,naive_fcst,\
                    avg_fcst,sma2,sma5,ses,holt,hwm]) #tm.strftime("%Y-%m-%d")
res_df = pd.DataFrame(res,columns=['key','timestamp','actual','forecast','stdErr','lowPrInt','upPrInt','naive',\
                                  'avg_fcst','sma2','sma5','ses','holt','hwm'])
# Out:
# ANAND MOTORS-139284
# Gulati Agencies Pvt. Ltd.-122310
# Gulati Agencies Pvt. Ltd.-122467
# Gulati Agencies Pvt. Ltd.-123336
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-130512
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139362
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139432
# Gulati Agencies Pvt. Ltd.-139433
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139434
# Gulati Agencies Pvt. Ltd.-139461
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-136071
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-139470
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-139471
# Hans Lubricants & Auto Spares Private Limited-139474
# Hans Lubricants & Auto Spares Private Limited-139487
# M/S Ramesh Marketing-139358
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# M/S Ramesh Marketing-139362
# MODI SALES AGENCY-139241
# MODI SALES AGENCY-139242
# MODI SALES AGENCY-139252
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# MODI SALES AGENCY-139261
# MODI SALES AGENCY-139438
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Mars Petrochem-122467
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Mars Petrochem-139242
# SVD did not converge
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-122310
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-139317
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-139332
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Punjab Agencies-139530
# SVD did not converge
# Punjab Agencies-139546
# Rajdeep & Associates-122292
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rajdeep & Associates-122310
# Rajdeep & Associates-139251
# SVD did not converge
# Rajdeep & Associates-139252
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rajdeep & Associates-139307
# SVD did not converge
# Raka Oil Company-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Raka Oil Company-130512
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Raka Oil Company-139250
# Raka Oil Company-139251
# SVD did not converge
# SVD did not converge
# Raka Oil Company-139252
# Raka Oil Company-139284
# Raka Oil Company-139343
# Raka Oil Company-139461
# Raka Oil Company-139530
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rotex PetroChem Private Limited-139358
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Rotex PetroChem Private Limited-139362
# Rotex PetroChem Private Limited-139471
# Rotex PetroChem Private Limited-139505
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Rotex PetroChem Private Limited-139530
# S R LUBRICANTS-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# S R LUBRICANTS-139251
# SVD did not converge
# SVD did not converge
# Sanjay Tools & Accessories Pvt Ltd-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Sanjay Tools & Accessories Pvt Ltd-122326
# Sanjay Tools & Accessories Pvt Ltd-122467
# Sanjay Tools & Accessories Pvt Ltd-130512
# Sanjay Tools & Accessories Pvt Ltd-135456
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# Sanjay Tools & Accessories Pvt Ltd-139250
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Sanjay Tools & Accessories Pvt Ltd-139251
# Spectrum Petromac Pvt. Ltd.-139252
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Spectrum Petromac Pvt. Ltd.-139613
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139284
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139314
# Speed A Way Pvt Ltd-139358
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139362
# Speed A Way Pvt Ltd-139464
# Speed A Way Pvt Ltd-139470
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Speed A Way Pvt Ltd-139473
# Speed A Way Pvt Ltd-139478
# Speed A Way Pvt Ltd-139505
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139542
# Speed A Way Pvt Ltd-139543
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Speed A Way Pvt Ltd-139546
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Speed A Way Pvt Ltd-139613
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Star Industrial Products-122310
# Star Industrial Products-122467
# Star Industrial Products-139250
# SVD did not converge
# Super Transports P Ltd-122310
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Super Transports P Ltd-122467
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-130512
# Super Transports P Ltd-135441
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139242
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139251
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139252
# Super Transports P Ltd-139306
# Super Transports P Ltd-139309
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139434
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Super Transports P Ltd-139462
# Super Transports P Ltd-139463
# Super Transports P Ltd-139464
# SVD did not converge
# Super Transports P Ltd-139465
# Super Transports P Ltd-139473
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139495
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139530
# Super Transports P Ltd-139542
# SVD did not converge
# SVD did not converge
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.

# %%
res = list()
for key in keys_model:
    ser = df.query('key == @key')['siv_demand'].sort_index()
    ser.fillna(0,inplace=True)
    ser1 = ser[ser<=ser.quantile(0.99)]
    #ser = ser[ser < ser.quantile(0.75)+ (ser.quantile(0.75)-ser.quantile(0.25))*2]
    tm_df = pd.DataFrame(index=base_time_frame)
    tm_df = pd.concat([tm_df,ser1],axis=1)
    sample_data = tm_df.copy()
    sample_data.loc[sample_data==0] = np.nan
    sample_data = sample_data.interpolate(method='time')
    tm_df.fillna(0,inplace=True)
    print(key)
    
    for tm in forecast_range:
        train_data = sample_data.loc[:tm][:-2]  # setting train data 2 months prior to forecast month
        demand_act = ser.loc[tm]
        naive_fcst = train_data.iloc[-1]
        avg_fcst =  train_data.mean()
        sma2 = train_data.rolling(2).mean().iloc[-1]
        sma5 = train_data.rolling(5).mean().iloc[-1]
        fit2 = SimpleExpSmoothing(np.asarray(train_data)).fit(smoothing_level=0.6,optimized=False)
        ses = fit2.forecast(2)[1]
        fit1 = Holt(np.asarray(train_data)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
        holt = fit1.forecast(2)[1]
        hwm_model = ExponentialSmoothing(np.asarray(train_data) ,seasonal_periods=7 ,trend='add', seasonal
                ='add',).fit()
        hwm = hwm_model.forecast(2)[1]
        #print(tm.date())
        fcst = 0
        stderr = 0
        up_conf = 0
        low_conf = 0
        try:
            model = ARIMA(train_data, order=(4,1,2))
            model_fit = model.fit(transparams=False,disp=-1,trend='c',maxiter = 5000)#start_params =5
            #print(model_fit.forecast())
            fcst,stderr,conf = model_fit.forecast(steps =2)
            fcst = 0 if np.isnan(round(fcst[1])) else round(fcst[1])
            stderr = 0 if np.isnan(round(stderr[1])) else round(stderr[1])
            low_conf = 0 if np.isnan(round(conf[1][0])) else round(conf[1][0])
            up_conf = 0 if np.isnan(round(conf[1][1])) else round(conf[1][1])
            #print(fcst,stderr)
        except Exception as e:
            print(e)
            fcst = 0
            fcst = 0
            stderr = 0
            up_conf = 0
            low_conf = 0
        
        res.append([key,tm,demand_act,fcst,stderr,low_conf,up_conf,naive_fcst,\
                    avg_fcst,sma2,sma5,ses,holt,hwm]) #tm.strftime("%Y-%m-%d")
res_df = pd.DataFrame(res,columns=['key','timestamp','actual','forecast','stdErr','lowPrInt','upPrInt','naive',\
                                  'avg_fcst','sma2','sma5','ses','holt','hwm'])
# Out:
# ANAND MOTORS-139284
# Gulati Agencies Pvt. Ltd.-122310
# Gulati Agencies Pvt. Ltd.-122467
# Gulati Agencies Pvt. Ltd.-123336
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-130512
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139362
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139432
# Gulati Agencies Pvt. Ltd.-139433
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Gulati Agencies Pvt. Ltd.-139434
# Gulati Agencies Pvt. Ltd.-139461
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-136071
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-139470
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Hans Lubricants & Auto Spares Private Limited-139471
# Hans Lubricants & Auto Spares Private Limited-139474
# Hans Lubricants & Auto Spares Private Limited-139487
# M/S Ramesh Marketing-139358
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# M/S Ramesh Marketing-139362
# MODI SALES AGENCY-139241
# MODI SALES AGENCY-139242
# MODI SALES AGENCY-139252
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# MODI SALES AGENCY-139261
# MODI SALES AGENCY-139438
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Mars Petrochem-122467
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Mars Petrochem-139242
# SVD did not converge
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-122310
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-139317
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# PON PURE CHEMICAL INDIA PRIVATE LIMITED-139332
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Punjab Agencies-139530
# SVD did not converge
# Punjab Agencies-139546
# Rajdeep & Associates-122292
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rajdeep & Associates-122310
# Rajdeep & Associates-139251
# SVD did not converge
# Rajdeep & Associates-139252
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rajdeep & Associates-139307
# SVD did not converge
# Raka Oil Company-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Raka Oil Company-130512
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Raka Oil Company-139250
# Raka Oil Company-139251
# SVD did not converge
# SVD did not converge
# Raka Oil Company-139252
# Raka Oil Company-139284
# Raka Oil Company-139343
# Raka Oil Company-139461
# Raka Oil Company-139530
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Rotex PetroChem Private Limited-139358
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Rotex PetroChem Private Limited-139362
# Rotex PetroChem Private Limited-139471
# Rotex PetroChem Private Limited-139505
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Rotex PetroChem Private Limited-139530
# S R LUBRICANTS-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# S R LUBRICANTS-139251
# SVD did not converge
# SVD did not converge
# Sanjay Tools & Accessories Pvt Ltd-122310
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Sanjay Tools & Accessories Pvt Ltd-122326
# Sanjay Tools & Accessories Pvt Ltd-122467
# Sanjay Tools & Accessories Pvt Ltd-130512
# Sanjay Tools & Accessories Pvt Ltd-135456
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# Sanjay Tools & Accessories Pvt Ltd-139250
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Sanjay Tools & Accessories Pvt Ltd-139251
# Spectrum Petromac Pvt. Ltd.-139252
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Spectrum Petromac Pvt. Ltd.-139613
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139284
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139314
# Speed A Way Pvt Ltd-139358
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139362
# Speed A Way Pvt Ltd-139464
# Speed A Way Pvt Ltd-139470
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Speed A Way Pvt Ltd-139473
# Speed A Way Pvt Ltd-139478
# Speed A Way Pvt Ltd-139505
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Speed A Way Pvt Ltd-139542
# Speed A Way Pvt Ltd-139543
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Speed A Way Pvt Ltd-139546
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Speed A Way Pvt Ltd-139613
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Star Industrial Products-122310
# Star Industrial Products-122467
# Star Industrial Products-139250
# SVD did not converge
# Super Transports P Ltd-122310
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Super Transports P Ltd-122467
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-130512
# Super Transports P Ltd-135441
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139242
# The computed initial AR coefficients are not stationary
# You should induce stationarity, choose a different model order, or you can
# pass your own start_params.
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139251
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139252
# Super Transports P Ltd-139306
# Super Transports P Ltd-139309
# SVD did not converge
# SVD did not converge
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139434
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.
# Super Transports P Ltd-139462
# Super Transports P Ltd-139463
# Super Transports P Ltd-139464
# SVD did not converge
# Super Transports P Ltd-139465
# Super Transports P Ltd-139473
# SVD did not converge
# SVD did not converge
# Super Transports P Ltd-139495
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# exog contains inf or nans
# Super Transports P Ltd-139530
# Super Transports P Ltd-139542
# SVD did not converge
# SVD did not converge
# The computed initial MA coefficients are not invertible
# You should induce invertibility, choose a different model order, or you can
# pass your own start_params.

# %%
# tm_df = df.query('key == @keys_model[0]')['siv_demand'].sort_index()

# tm_df.loc[tm_df==0] = np.nan

# sample_data = tm_df.interpolate(method='time')

# train_data = sample_data.loc[:forecast_range[0]][:-2]

# fit2 = SimpleExpSmoothing(np.asarray(train_data)).fit(smoothing_level=0.6,optimized=False)

# fit1 = Holt(np.asarray(train_data)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)

# fit1.forecast(2)[1]

# model = ARIMA(train_data, order=(4,1,2))
# model_fit = model.fit(transparams=False,disp=-1,trend='c',maxiter = 5000)#start_params =5
# #print(model_fit.forecast())
# fcst,stderr,conf = model_fit.forecast(steps =2)

# %%
df_19['key'] = df_19.Distributor.astype(str)+"-"+df_19.Material.astype(str)

df_19.columns = ['Brand Architecture', 'Distributor', 'Distributor_AR', 'Material', \
                'timestamp', 'Package Group', 'Product Family', \
                'Product Line', 'Synthetic Indicator', 'Month', 'EMAPS_Forecast', \
                'ICB', 'SIV', 'SOV', 'key']

res_df_2 = pd.merge(res_df,df_19[['key','EMAPS_Forecast','timestamp']],how='left',on=['key','timestamp'])

model_cols =  ['forecast','naive', 'avg_fcst', 'sma2', 'sma5', 'ses', 'holt', 'hwm','EMAPS_Forecast']
error_ser = res_df_2.loc[:,model_cols].apply(lambda x: x - res_df_2.actual)

# %%
res_df_2.forecast.quantile([0.03,0.99])
# Out:
# 0.03        0.00
# 0.99   60,891.00
# Name: forecast, dtype: float64

# %%
res_df_2.loc[res_df_2.forecast >= 61000,'forecast'] = res_df_2.naive
res_df_2.loc[res_df_2.forecast < 0,'forecast'] = res_df_2.naive

# %%
mae_error = res_df_2.loc[:,model_cols].apply(lambda x: x - res_df_2.actual,axis=0).abs().mean(axis=0)

# %%
mae_error
# Out:
# forecast         3,844.70
# naive            4,264.11
# avg_fcst         3,443.37
# sma2             3,807.32
# sma5             3,436.11
# ses              3,758.32
# holt             3,514.81
# hwm              3,636.85
# EMAPS_Forecast   2,974.32
# dtype: float64

# %%
res_df_2.to_excel('long_term_model_results.xlsx',index=False)

# %%
res = list()
for key in keys_model:
    ser = df.query('key == @key')['siv_demand'].sort_index()
    ser.fillna(0,inplace=True)
    ser1 = ser[ser<=ser.quantile(0.99)]
    #ser = ser[ser < ser.quantile(0.75)+ (ser.quantile(0.75)-ser.quantile(0.25))*2]
    tm_df = pd.DataFrame(index=base_time_frame)
    tm_df = pd.concat([tm_df,ser1],axis=1)
    sample_data = tm_df.copy()
    print(sample_data.head())
    sample_data[sample_data==0] = np.nan
    sample_data = sample_data.interpolate(method='time')
    tm_df.fillna(0,inplace=True)
    print(key)
    
    for tm in forecast_range:
        train_data = sample_data.loc[:tm][:-2]  # setting train data 2 months prior to forecast month
        demand_act = ser.loc[tm]

        fit2 = SimpleExpSmoothing(np.asarray(train_data)).fit(smoothing_level=0.3,optimized=False)
        ses = fit2.forecast(2)[1]
        fit1 = Holt(np.asarray(train_data)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
        holt = fit1.forecast(2)[1]
        hwm_model = ExponentialSmoothing(np.asarray(train_data) ,seasonal_periods=5 ,trend='add', seasonal
                ='add',).fit()
        hwm = hwm_model.forecast(2)[1]
        
        
        res.append([key,tm,demand_act,ses,holt,hwm]) #tm.strftime("%Y-%m-%d")
res_df_3 = pd.DataFrame(res,columns=['key','timestamp','actual','ses','holt','hwm'])
# Out:
#             siv_demand
# 2016-01-01    1,040.02
# 2016-02-01    1,664.09
# 2016-03-01    2,496.14
# 2016-04-01    3,120.22
# 2016-05-01    4,368.37
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-0307e7e6db13> in <module>()
#       9     sample_data = tm_df.copy()
#      10     print(sample_data.head())
# ---> 11     sample_data.loc[sample_data==0] = np.nan
#      12     sample_data = sample_data.interpolate(method='time')
#      13     tm_df.fillna(0,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     138         else:
#     139             key = com._apply_if_callable(key, self.obj)
# --> 140         indexer = self._get_setitem_indexer(key)
#     141         self._setitem_with_indexer(indexer, value)
#     142
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     125
#     126         try:
# --> 127             return self._convert_to_indexer(key, is_setter=True)
#     128         except TypeError as e:
#     129
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1228                 mask = check == -1
#    1229                 if mask.any():
# -> 1230                     raise KeyError('%s not in index' % objarr[mask])
#    1231
#    1232                 return _values_from_object(indexer)
#
# KeyError: "[('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')\n ('s', 'i', 'v', '_', 'd', 'e', 'm', 'a', 'n', 'd')] not in index"

# %%
model_cols =  ['ses', 'holt', 'hwm']
mae_error = res_df_3.loc[:,model_cols].apply(lambda x: x - res_df_3.actual,axis=0).abs().mean(axis=0)
mae_error
